# %%
# !pip3 install proxyscrape

# %%
from proxyscrape import create_collector
import scholarly
from build_bib import get_files, get_refs

# %%
collector = create_collector('my-collector', resources=['proxy-daily-socks5'])

# %%
titles = []
# get this file
for fp in get_files("files"):
    
    # get title
    for title in get_refs(fp):

        titles.append(title)

print(f"found {len(set(titles))} titles.")
# Out:
# File: files/CNN_LOC_am8_st17_sp9.pdf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ff10d2735866> in <module>
#       4
#       5     # get title
# ----> 6     for title in get_refs(fp):
#       7
#       8         titles.append(title)
#
# /mnt/d/ubuntu18.04/Projects/RefMan/build_bib.py in get_refs(file_path)
#       6     """list of references in pdf file"""
#       7     print("File:", file_path)
# ----> 8     refs = refextract.extract_references_from_file(str(file_path))
#       9
#      10     # iterate over refs
#
# ~/.local/share/virtualenvs/RefMan-ttoYzLgb/lib/python3.6/site-packages/refextract/references/api.py in extract_references_from_file(path, recid, reference_format, linker_callback, override_kbs_files)
#     126         raise FullTextNotAvailableError(u"File not found: '{0}'".format(path))
#     127
# ...

# %%
titles
# Out:
# ['an indoor localization mechanism using active rfid tag',
#  'modeling rfid signal distribution based on neural network combined with continuous ant colony optimization',
#  'ujiindoorloc: a new multi-building and multi-floor database for wlan fingerprint-based indoor localization problems',
#  'learnloc: a framework for smart indoor localization with embedded mobile devices',
#  'a tutorial survey of architectures, algorithms, and applications for deep learning',
#  'walrus: wireless acoustic location with room-level resolution using ultrasound',
#  'wifi-based indoor positioning',
#  'radar: an in-building rfbased user location and tracking system',
#  'deep neural networks for wireless localization in indoor and outdoor environments',
#  'deepfi: deep learning for indoor fingerprinting using channel state information',
#  'confi: convolutional neural networks based indoor wi-fi localization using channel state information',
#  'deep belief networks and deep learning',
# ...
